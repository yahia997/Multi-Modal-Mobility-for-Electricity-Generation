# %%
import sys
sys.path.append('../lib') 
from pyspark.sql.functions import *
from pyspark.sql.types import *
import pandas as pd
import matplotlib.pyplot as plt
from pyspark.sql import Window

# %%
from load_netmob import Load_NetMob

df = Load_NetMob()
# Out:
# initializing spark session ...
# merging datasets ...
# merging with trips ...

# %%
df.remove_blurring()
# Out:
# Remove blurring effect ...

# %%
sample = df.data.filter(col('KEY') == '42_0013-thursday-44854-3').toPandas()

sample.to_csv('./raw_trip_blurring_removed.csv')
